# %%
import pandas as pd
import os
from os.path import isfile, join
from os import listdir
import math
from path import Path



def amplitude(val):
    global noise
    if val == '0j' or val == '' or val == '0':
        return noise
    comp = complex(val)
    real = comp.real  #extract real part and convert to a float
    imaginary = comp.imag #remove the space between the sign and number for imaginary and convert to float
    
    refLevDBM = 30
    absComplex = abs(complex(real, imaginary))
    
    try:
        sigDB = 20* math.log(absComplex, 10)
        
    except:
        print("val is " + str(val))
        print("abscomplex is " + str(absComplex))
        print(sigDB)
        sys.exit()
        
    sigDBM = sigDB + 30 - refLevDBM
    
    return sigDBM #complex takes two floats, real and imaginary, and creates a complex number, return that complex number


def getDeviceName(subdir):
    i = -1
    device = ''
    while abs(i) < len(subdir):
        if not subdir[i] == '\\':
            device += subdir[i]
            i -= 1
        else:
            return device[::-1]


path = r'Bursts'

def makeFeatures(path):
    my_directory = Path(path)
    subdirs = my_directory.dirs()
    
    df = pd.DataFrame()
    
    for subdir in subdirs:
        print(subdir)
        bursts = [f for f in listdir(subdir) if isfile(join(subdir, f))]
        device = getDeviceName(subdir)
        
        for file in bursts:
            filePath = subdir + '\\' + file
            data = pd.read_excel(filePath)
            data[0] = data[0].apply(amplitude)
            data = data.rename(columns = {0 : 'Amplitude'})
            data = data.rename(columns = {'Unnamed: 0': 'Time'})
            data['Device'] = device
            
            timeseries, 
            print(data)
makeFeatures(path)
# Out:
# Bursts\Apple watch
#           Time   Amplitude       Device
# 0            0  -82.727417  Apple watch
# 1            1  -91.700365  Apple watch
# 2            2  -84.536242  Apple watch
# 3            3  -95.743822  Apple watch
# 4            4  -99.911491  Apple watch
# 5            5  -87.665195  Apple watch
# 6            6  -89.613732  Apple watch
# 7            7  -89.023348  Apple watch
# 8            8  -87.173365  Apple watch
# 9            9  -86.191826  Apple watch
# 10          10  -94.332513  Apple watch
# 11          11  -87.827965  Apple watch
# 12          12  -86.149512  Apple watch
# 13          13  -97.631492  Apple watch
# 14          14 -101.020860  Apple watch
# 15          15  -99.988272  Apple watch
# 16          16  -96.992661  Apple watch
# 17          17  -94.824755  Apple watch
# 18          18  -83.723209  Apple watch
# 19          19 -105.330835  Apple watch
# 20          20  -88.426109  Apple watch
# 21          21  -97.855037  Apple watch
# 22          22  -94.464507  Apple watch
# 23          23  -86.908285  Apple watch
# 24          24  -88.942669  Apple watch
# 25          25  -82.556916  Apple watch
# 26          26  -84.429691  Apple watch
# 27          27  -98.966736  Apple watch
# 28          28  -88.496352  Apple watch
# 29          29  -91.029282  Apple watch
# ...        ...         ...          ...
# 328580  328580  -88.082848  Apple watch
# 328581  328581  -92.393796  Apple watch
# 328582  328582  -88.095324  Apple watch
# 328583  328583  -97.798449  Apple watch
# 328584  328584  -87.319863  Apple watch
# 328594  328594  -88.740343  Apple watch
# 328595  328595  -88.585380  Apple watch
# 328596  328596  -87.406613  Apple watch
# 328597  328597  -85.704808  Apple watch
# 328598  328598  -89.721993  Apple watch
# 328599  328599  -93.723661  Apple watch
# 328600  328600  -86.625160  Apple watch
# 328601  328601  -88.556380  Apple watch
# 328602  328602  -93.996855  Apple watch
# 328603  328603  -88.999450  Apple watch
# 328604  328604  -88.691819  Apple watch
# 328605  328605  -91.043677  Apple watch
# 328606  328606  -91.058126  Apple watch
# 328607  328607  -90.756460  Apple watch
# 328608  328608  -91.163063  Apple watch
# 328609  328609  -87.867398  Apple watch
#
# [328610 rows x 3 columns]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-7724a548012e> in <module>
#      65             data['Device'] = device
#      66             print(data)
# ---> 67 makeFeatures(path)
#      68
#
# <ipython-input-19-7724a548012e> in makeFeatures(path)
#      59         for file in bursts:
#      60             filePath = subdir + '\\' + file
# ---> 61             data = pd.read_excel(filePath)
#      62             data[0] = data[0].apply(amplitude)
#      63             data = data.rename(columns = {0 : 'Amplitude'})
#
# ~\AppData\Local\Continuum\miniconda3\envs\ml\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
#     190     return _deprecate_kwarg
#
# ~\AppData\Local\Continuum\miniconda3\envs\ml\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
#     190     return _deprecate_kwarg
#
# ~\AppData\Local\Continuum\miniconda3\envs\ml\lib\site-packages\pandas\io\excel.py in read_excel(io, sheet_name, header, names, index_col, parse_cols, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skip_footer, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     348
#     349     if not isinstance(io, ExcelFile):
# --> 350         io = ExcelFile(io, engine=engine)
#     351
#     352     return io.parse(
#
# ~\AppData\Local\Continuum\miniconda3\envs\ml\lib\site-packages\pandas\io\excel.py in __init__(self, io, engine)
#     651         self._io = _stringify_path(io)
#     652
# --> 653         self._reader = self._engines[engine](self._io)
#     654
#     655     def __fspath__(self):
#
# ~\AppData\Local\Continuum\miniconda3\envs\ml\lib\site-packages\pandas\io\excel.py in __init__(self, filepath_or_buffer)
#     422             self.book = xlrd.open_workbook(file_contents=data)
#     423         elif isinstance(filepath_or_buffer, compat.string_types):
# --> 424             self.book = xlrd.open_workbook(filepath_or_buffer)
#     425         else:
#     426             raise ValueError('Must explicitly set engine if not passing in'
#
# ~\AppData\Local\Continuum\miniconda3\envs\ml\lib\site-packages\xlrd\__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     136                 formatting_info=formatting_info,
#     137                 on_demand=on_demand,
# --> 138                 ragged_rows=ragged_rows,
#     139             )
#     140             return bk
#
# ~\AppData\Local\Continuum\miniconda3\envs\ml\lib\site-packages\xlrd\xlsx.py in open_workbook_2007_xml(zf, component_names, logfile, verbosity, use_mmap, formatting_info, on_demand, ragged_rows)
#     839         x12sheet = X12Sheet(sheet, logfile, verbosity)
#     840         heading = "Sheet %r (sheetx=%d) from %r" % (sheet.name, sheetx, fname)
# --> 841         x12sheet.process_stream(zflo, heading)
#     842         del zflo
#     843
#
# ~\AppData\Local\Continuum\miniconda3\envs\ml\lib\site-packages\xlrd\xlsx.py in own_process_stream(self, stream, heading)
#     546         row_tag = U_SSML12 + "row"
#     547         self_do_row = self.do_row
# --> 548         for event, elem in ET.iterparse(stream):
#     549             if elem.tag == row_tag:
#     550                 self_do_row(elem)
#
# ~\AppData\Local\Continuum\miniconda3\envs\ml\lib\xml\etree\ElementTree.py in iterator()
#    1222                 yield from pullparser.read_events()
#    1223                 # load event buffer
# -> 1224                 data = source.read(16 * 1024)
#    1225                 if not data:
#    1226                     break
#
# ~\AppData\Local\Continuum\miniconda3\envs\ml\lib\zipfile.py in read(self, n)
#     897         self._offset = 0
#     898         while n > 0 and not self._eof:
# --> 899             data = self._read1(n)
#     900             if n < len(data):
#     901                 self._readbuffer = data
#
# ~\AppData\Local\Continuum\miniconda3\envs\ml\lib\zipfile.py in _read1(self, n)
#     973         elif self._compress_type == ZIP_DEFLATED:
#     974             n = max(n, self.MIN_READ_SIZE)
# --> 975             data = self._decompressor.decompress(data, n)
#     976             self._eof = (self._decompressor.eof or
#     977                          self._compress_left <= 0 and
#
# KeyboardInterrupt:
