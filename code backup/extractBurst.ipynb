# %%
# This program is meant to help build features 
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy.interpolate import spline
from os import listdir
import os
from os.path import isfile, join
import shutil
from scipy import signal
import sys
from tsfresh import extract_features
from tsfresh import select_features
from tsfresh.utilities.dataframe_functions import impute
from tsfresh import extract_relevant_features

def getDeviceName(subdir):
    i = -1
    device = ''
    while abs(i) < len(subdir):
        if not subdir[i] == '\\':
            device += subdir[i]
            i -= 1
        else:
            return device[::-1]
        
def getBurstNum(file):
    i = -1
    num = ''
    
    while abs(i) < len(file):
        if not file[i] == '.':
            i -= 1
            
        else:
            i-=1
            while abs(i) < len(file) and file[i] != 't': 
                num += file[i]
                i-=1
                    
            return int(num[::-1])
        
        
def deviceArr(path):
    
    devices = []
    
    subdirs = [f.path for f in os.scandir(path) if f.is_dir() ]
    i = 0
    for subdir in subdirs:
        devices.insert(i, getDeviceName(subdir))
        i+=1
    return devices
    
    
if __name__ == '__main__':
    path = r'AsExcel'
    devices = deviceArr(path)
    print(devices)
    
    subdirs = [f.path for f in os.scandir(path) if f.is_dir() ]
    
    
    for device in devices:
        subdir = path + '//' + device
        bursts = [f for f in listdir(subdir) if isfile(join(subdir, f))]
        
        size = len(bursts) * 2 # we expect each burst to contain 2 bursts
        
        df = pd.DataFrame(index = range(size), columns = ['Time', 'Amplitude', 'PeakNumber'])
        i = 0
        for file in bursts:
            fileDir = path + '//' + device + '//' + file
            print(fileDir)
            data = pd.read_excel(fileDir)
            data['Device'] = device
            
            data.to_excel(fileDir)
# Out:
# ['Gian Iphone (pyle)', 'Portable_ECG_2_(replay Hack2)']
# AsExcel//Gian Iphone (pyle)//Burst002.xlsx
# AsExcel//Gian Iphone (pyle)//Burst005.xlsx
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-af84a1a58d34> in <module>
#      77             data['Device'] = device
#      78
# ---> 79             data.to_excel(fileDir)
#
# ~\Miniconda3\envs\machinelearning\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    2125         formatter.write(excel_writer, sheet_name=sheet_name, startrow=startrow,
#    2126                         startcol=startcol, freeze_panes=freeze_panes,
# -> 2127                         engine=engine)
#    2128
#    2129     def to_json(self, path_or_buf=None, orient=None, date_format=None,
#
# ~\Miniconda3\envs\machinelearning\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
#     662                            freeze_panes=freeze_panes)
#     663         if need_save:
# --> 664             writer.save()
#
# ~\Miniconda3\envs\machinelearning\lib\site-packages\pandas\io\excel.py in save(self)
#    1226         Save workbook to disk.
#    1227         """
# -> 1228         return self.book.save(self.path)
#    1229
#    1230     @classmethod
#
# ~\Miniconda3\envs\machinelearning\lib\site-packages\openpyxl\workbook\workbook.py in save(self, filename)
#     395         if self.write_only and not self.worksheets:
#     396             self.create_sheet()
# --> 397         save_workbook(self, filename)
#     398
#     399
#
# ~\Miniconda3\envs\machinelearning\lib\site-packages\openpyxl\writer\excel.py in save_workbook(workbook, filename)
#     292     archive = ZipFile(filename, 'w', ZIP_DEFLATED, allowZip64=True)
#     293     writer = ExcelWriter(workbook, archive)
# --> 294     writer.save()
#     295     return True
#     296
#
# ~\Miniconda3\envs\machinelearning\lib\site-packages\openpyxl\writer\excel.py in save(self)
#     274     def save(self):
#     275         """Write data into the archive."""
# --> 276         self.write_data()
#     277         self._archive.close()
#     278
#
# ~\Miniconda3\envs\machinelearning\lib\site-packages\openpyxl\writer\excel.py in write_data(self)
#      74             archive.writestr(ARC_THEME, theme_xml)
#      75
# ---> 76         self._write_worksheets()
#      77         self._write_chartsheets()
#      78         self._write_images()
#
# ~\Miniconda3\envs\machinelearning\lib\site-packages\openpyxl\writer\excel.py in _write_worksheets(self)
#     214
#     215             ws._id = idx
# --> 216             self.write_worksheet(ws)
#     217
#     218             if ws._drawing:
#
# ~\Miniconda3\envs\machinelearning\lib\site-packages\openpyxl\writer\excel.py in write_worksheet(self, ws)
#     199         else:
#     200             writer = WorksheetWriter(ws)
# --> 201             writer.write()
#     202
#     203         ws._rels = writer._rels
#
# ~\Miniconda3\envs\machinelearning\lib\site-packages\openpyxl\worksheet\_writer.py in write(self)
#     354         """
#     355         self.write_top()
# --> 356         self.write_rows()
#     357         self.write_tail()
#     358         self.close()
#
# ~\Miniconda3\envs\machinelearning\lib\site-packages\openpyxl\worksheet\_writer.py in write_rows(self)
#     121
#     122         with xf.element("sheetData"):
# --> 123             for row_idx, row in self.rows():
#     124                 self.write_row(xf, row, row_idx)
#     125
#
# KeyboardInterrupt:
