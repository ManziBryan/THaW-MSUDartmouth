# %%
# This program is meant to help save the bursts in a large dataframe/excel file containing a lot of noise
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
from os import listdir
import os
from os.path import isfile, join
import shutil
from scipy import signal
import sys
# from tsfresh import extract_features
# from tsfresh import select_features
# from tsfresh.utilities.dataframe_functions import impute
# from tsfresh import extract_relevant_features


noise = -85

class Peak:
    def __init__(self, start, end, height):
        self.start = start
        self.end = end
        self.width = end - start
        self.height = height
    def getStart(self):
        return self.start
    def getEnd(self):
        return self.end
    def getWidth(self):
        return self.width
    def getHeight(self):
        return self.height               
    def __str__(self):
        return "START: " + str(self.start) + "; END: " + str(self.end) + "; WIDTH: " + str(self.width) + "; HEIGHT: " + str(self.height)
    def __repr__(self):
        return str(self) + '\n'

    
def amplitude(val):
    global noise
    if val == '0j' or val == '' or val == '0':
        return noise
    comp = complex(val)
    real = comp.real  #extract real part and convert to a float
    imaginary = comp.imag #remove the space between the sign and number for imaginary and convert to float
    
    refLevDBM = 30
    absComplex = abs(complex(real, imaginary))
    
    try:
        sigDB = 20* math.log(absComplex, 10)
        
    except:
        print("val is " + str(val))
        print("abscomplex is " + str(absComplex))
        print(sigDB)
        sys.exit()
        
    sigDBM = sigDB + 30 - refLevDBM
    
    return sigDBM #complex takes two floats, real and imaginary, and creates a complex number, return that complex number

# what I want to do is write something which tells me when the slope has suddenly changed....
# alternatively I could have something which tells me when the mean amplitude has changed,
# tells me the exact location for the change if the average is above noise for 4000 samples
# add start end and width to possible peaks
def identifyPeaks(data):
    df = data.copy()
    
    numSamples = df.index.max()
    jumpBy = 1000
    roll = 100
    df['Amplitude'] = df['Amplitude'].rolling(roll).mean(center = True)
    i = 0
    peaks = []
    
    if numSamples < minWidth:
        return []
    
    while i < df.index.max():
        end = 0
        start = 0
        amp = df['Amplitude'][i]
        if amp >= noise:
            while amp >= noise and i >= 0: #looks for peak's exact start
                i-=1
                amp = df['Amplitude'][i]
                
            start = i
            amp = df['Amplitude'][i+1]
            while amp >= noise and i + 100 <= numSamples :
                i+=100
                amp = df['Amplitude'][i]
                
            while amp <= noise and i >= 0:
                i-=1
                amp = df['Amplitude'][i]
                end = i
                
            if end - start >= minWidth and end != 0 and start != roll - 2:
                
                plt.plot(data['Amplitude'][max(0, start - 200) : min(end + 200, numSamples)])
                plt.savefig(savePlotsTo + '//' + device + '//' +str(burstNum)+ "_" + str(len(peaks)))
                plt.cla()
                
                center = (start + end) // 2
                centerLeft = (center + start)//2
                centerRight = (center + end)//2
            
                height = df['Amplitude'][centerLeft: centerRight].mean()
                newPeak = Peak(start, end, height)
                peaks.append(newPeak)
            else:
                print(end)
                print(start)
        i+=jumpBy
    
#     print(peaks)
    
    if len(peaks) > 2:
        peaks = twoHighest(peaks)
    
    return peaks

def twoHighest(peaks):
    
    if len(peaks) == 2:
        return peaks
    
    elif len(peaks) == 1:
        zeroPeak = Peak(0, 0, 0)
        peaks.append(zeroPeak)
        return peaks
    
    elif len(peaks) == 0:
        zeroPeak = Peak(0, 0, 0)
        zeroPeak2 = Peak(0, 0, 0)
        peaks.append(zeroPeak)
        peaks.append(zeroPeak2)
        return peaks
    
    else:
        peaks.sort(key = Peak.getHeight)
#         print(peaks)
        peaks = peaks[-2:]
        peaks.sort(key = Peak.getStart)
        return peaks

def getDeviceName(subdir):
    i = -1
    device = ''
    while abs(i) < len(subdir):
        if not subdir[i] == '/':
            device += subdir[i]
            i -= 1
        else:
            return device[::-1]
        
def getBurstNum(file):
    i = -1
    num = ''
    
    while abs(i) < len(file):
        if not file[i] == '.':
            i -= 1
            
        else:
            i-=1
            while abs(i) < len(file) and file[i] != 't': 
                num += file[i]
                i-=1
                    
            return int(num[::-1])
        
        
def deviceArr(path):
    
    devices = []
    
    subdirs = [f.path for f in os.scandir(path) if f.is_dir() ]
    
    i = 0
    for subdir in subdirs:
        devices.insert(i, getDeviceName(subdir))
        i+=1
    return devices

def makeDir(pathWay):
    if os.path.isdir(pathWay):
        shutil.rmtree(pathWay)
        
    os.mkdir(pathWay)

if __name__ == "__main__":
    # assumptions, there is a directory which has folders labelled by device name. The folder contains amplitude information. 
    # requirements: must be able to pick up the two strongest plateaus
    # will use python peak detection to find out the two or one peaks worth looking at. Will look at the most prominent peaks
    # first.
    path = r'AsExcel'
    savePlotsTo = r'PlotsAll'
    newBursts = r'smallBursts'
    samplingRate = 112*(10**6) # sampling rate of collection device in samples/second
    minLength = 40/(10**6) # min length of a bluetooth packet (8us for preamble and 32us for access address) in seconds
    minWidth = minLength * samplingRate #minwidth is 4480samples
    
    devices = deviceArr(path)
    
    subdirs = [f.path for f in os.scandir(path) if f.is_dir() ]
    
    makeDir(savePlotsTo)
    makeDir(newBursts)
    
    
    for device in devices:
        makeDir(savePlotsTo + '/' + device) #make folder to save plots to
        makeDir(newBursts + '/' + device)
        
        print(device)
        subdir = path + '/' + device
        
        bursts = [f for f in listdir(subdir) if isfile(join(subdir, f))]
        
        size = len(bursts) * 2 # we expect each burst to contain 2 bursts
        
        df = pd.DataFrame(index = range(size), columns = ['Time', 'Amplitude', 'PeakNumber'])
        i = 0
        for file in bursts:
            burstNum = getBurstNum(file)
            fileDir = path + '/' + device + '/' + file
            print(fileDir)
            data = pd.read_excel(fileDir)
            data = data.rename(columns = {0 : 'Amplitude'})
            data['Amplitude'] = data['Amplitude'].apply(amplitude) # convert to amplitude
            data = data.rename(columns = {'Unnamed: 0': 'Time'})
            data['Time'] = data.index
            data['Device'] = device
            
            peaks = identifyPeaks(data)
            toSave = pd.DataFrame(columns = df.columns)
            
            
            label = '(a)'
            for peak in peaks:
                
                
                toSave = data[peak.start : peak.end]
                
                toSave.to_excel(newBursts + '/' + device + '/' + file[:-5] + label + '.xlsx')
                label = '(b)'
                
            plt.plot(data['Amplitude'])
            plt.savefig(savePlotsTo + '/' + device + '/' + str(burstNum))
            plt.cla()
# Out:
# iHealth Blood Pressure1
# AsExcel/iHealth Blood Pressure1/Burst114.xlsx
# AsExcel/iHealth Blood Pressure1/Burst051.xlsx
# AsExcel/iHealth Blood Pressure1/Burst143.xlsx
# 161539
# 162771
# 162592
# 163996
# 163725
# AsExcel/iHealth Blood Pressure1/Burst160.xlsx
# AsExcel/iHealth Blood Pressure1/Burst025.xlsx
# AsExcel/iHealth Blood Pressure1/Burst249.xlsx
# AsExcel/iHealth Blood Pressure1/Burst052.xlsx
# AsExcel/iHealth Blood Pressure1/Burst117.xlsx
# 160159
# 158457
# 161445
# 161064
# 162799
# 162426
# 164004
# 163592
# AsExcel/iHealth Blood Pressure1/Burst005.xlsx
# 141125
# 140941
# 142340
# 142047
# 143470
# 143105
# 144586
# 144449
# AsExcel/iHealth Blood Pressure1/Burst140.xlsx
# AsExcel/iHealth Blood Pressure1/Burst013.xlsx
# AsExcel/iHealth Blood Pressure1/Burst156.xlsx
# AsExcel/iHealth Blood Pressure1/Burst228.xlsx
# AsExcel/iHealth Blood Pressure1/Burst044.xlsx
# AsExcel/iHealth Blood Pressure1/Burst101.xlsx
# AsExcel/iHealth Blood Pressure1/Burst253.xlsx
# AsExcel/iHealth Blood Pressure1/Burst195.xlsx
# AsExcel/iHealth Blood Pressure1/Burst204.xlsx
# AsExcel/iHealth Blood Pressure1/Burst087.xlsx
# AsExcel/iHealth Blood Pressure1/Burst068.xlsx
# AsExcel/iHealth Blood Pressure1/Burst212.xlsx
# AsExcel/iHealth Blood Pressure1/Burst091.xlsx
# AsExcel/iHealth Blood Pressure1/Burst245.xlsx
# AsExcel/iHealth Blood Pressure1/Burst183.xlsx
# AsExcel/iHealth Blood Pressure1/Burst029.xlsx
# Gian Iphone (feversense)
# AsExcel/Gian Iphone (feversense)/Burst051.xlsx
# AsExcel/Gian Iphone (feversense)/Burst006.xlsx
# AsExcel/Gian Iphone (feversense)/Burst010.xlsx
# AsExcel/Gian Iphone (feversense)/Burst102.xlsx
# AsExcel/Gian Iphone (feversense)/Burst047.xlsx
# AsExcel/Gian Iphone (feversense)/Burst084.xlsx
# AsExcel/Gian Iphone (feversense)/Burst092.xlsx
# AsExcel/Gian Iphone (feversense)/Burst030.xlsx
# AsExcel/Gian Iphone (feversense)/Burst067.xlsx
# AsExcel/Gian Iphone (feversense)/Burst088.xlsx
# AsExcel/Gian Iphone (feversense)/Burst071.xlsx
# AsExcel/Gian Iphone (feversense)/Burst026.xlsx
# AsExcel/Gian Iphone (feversense)/Burst027.xlsx
# AsExcel/Gian Iphone (feversense)/Burst070.xlsx
# AsExcel/Gian Iphone (feversense)/Burst066.xlsx
# AsExcel/Gian Iphone (feversense)/Burst089.xlsx
# AsExcel/Gian Iphone (feversense)/Burst031.xlsx
# AsExcel/Gian Iphone (feversense)/Burst093.xlsx
# AsExcel/Gian Iphone (feversense)/Burst085.xlsx
# AsExcel/Gian Iphone (feversense)/Burst103.xlsx
# AsExcel/Gian Iphone (feversense)/Burst046.xlsx
# AsExcel/Gian Iphone (feversense)/Burst011.xlsx
# AsExcel/Gian Iphone (feversense)/Burst007.xlsx
# AsExcel/Gian Iphone (feversense)/Burst050.xlsx
# AsExcel/Gian Iphone (feversense)/Burst036.xlsx
# AsExcel/Gian Iphone (feversense)/Burst061.xlsx
# AsExcel/Gian Iphone (feversense)/Burst077.xlsx
# AsExcel/Gian Iphone (feversense)/Burst098.xlsx
# AsExcel/Gian Iphone (feversense)/Burst020.xlsx
# AsExcel/Gian Iphone (feversense)/Burst057.xlsx
# AsExcel/Gian Iphone (feversense)/Burst000.xlsx
# AsExcel/Gian Iphone (feversense)/Burst016.xlsx
# AsExcel/Gian Iphone (feversense)/Burst104.xlsx
# AsExcel/Gian Iphone (feversense)/Burst041.xlsx
# AsExcel/Gian Iphone (feversense)/Burst082.xlsx
# AsExcel/Gian Iphone (feversense)/Burst094.xlsx
# AsExcel/Gian Iphone (feversense)/Burst095.xlsx
# AsExcel/Gian Iphone (feversense)/Burst083.xlsx
# AsExcel/Gian Iphone (feversense)/Burst105.xlsx
# AsExcel/Gian Iphone (feversense)/Burst040.xlsx
# AsExcel/Gian Iphone (feversense)/Burst017.xlsx
# AsExcel/Gian Iphone (feversense)/Burst001.xlsx
# AsExcel/Gian Iphone (feversense)/Burst056.xlsx
# AsExcel/Gian Iphone (feversense)/Burst021.xlsx
# 62686
# 61611
# 64370
# 63673
# 65492
# 65018
# 66724
# 66370
# 67731
# 67540
# 70585
# 68718
# 72934
# 72302
# 75226
# 73586
# AsExcel/Gian Iphone (feversense)/Burst076.xlsx
# AsExcel/Gian Iphone (feversense)/Burst099.xlsx
# AsExcel/Gian Iphone (feversense)/Burst060.xlsx
# AsExcel/Gian Iphone (feversense)/Burst037.xlsx
# AsExcel/Gian Iphone (feversense)/Burst022.xlsx
# AsExcel/Gian Iphone (feversense)/Burst075.xlsx
# AsExcel/Gian Iphone (feversense)/Burst063.xlsx
# AsExcel/Gian Iphone (feversense)/Burst034.xlsx
# AsExcel/Gian Iphone (feversense)/Burst018.xlsx
# AsExcel/Gian Iphone (feversense)/Burst059.xlsx
# AsExcel/Gian Iphone (feversense)/Burst096.xlsx
# AsExcel/Gian Iphone (feversense)/Burst079.xlsx
# AsExcel/Gian Iphone (feversense)/Burst080.xlsx
# AsExcel/Gian Iphone (feversense)/Burst038.xlsx
# AsExcel/Gian Iphone (feversense)/Burst043.xlsx
# AsExcel/Gian Iphone (feversense)/Burst106.xlsx
# AsExcel/Gian Iphone (feversense)/Burst014.xlsx
# AsExcel/Gian Iphone (feversense)/Burst002.xlsx
# AsExcel/Gian Iphone (feversense)/Burst055.xlsx
# AsExcel/Gian Iphone (feversense)/Burst054.xlsx
# AsExcel/Gian Iphone (feversense)/Burst003.xlsx
# AsExcel/Gian Iphone (feversense)/Burst015.xlsx
# AsExcel/Gian Iphone (feversense)/Burst042.xlsx
# AsExcel/Gian Iphone (feversense)/Burst107.xlsx
# AsExcel/Gian Iphone (feversense)/Burst039.xlsx
# AsExcel/Gian Iphone (feversense)/Burst081.xlsx
# AsExcel/Gian Iphone (feversense)/Burst097.xlsx
# AsExcel/Gian Iphone (feversense)/Burst078.xlsx
# AsExcel/Gian Iphone (feversense)/Burst058.xlsx
# AsExcel/Gian Iphone (feversense)/Burst019.xlsx
# AsExcel/Gian Iphone (feversense)/Burst035.xlsx
# AsExcel/Gian Iphone (feversense)/Burst062.xlsx
# AsExcel/Gian Iphone (feversense)/Burst074.xlsx
# AsExcel/Gian Iphone (feversense)/Burst023.xlsx
# AsExcel/Gian Iphone (feversense)/Burst028.xlsx
# AsExcel/Gian Iphone (feversense)/Burst090.xlsx
# AsExcel/Gian Iphone (feversense)/Burst086.xlsx
# AsExcel/Gian Iphone (feversense)/Burst069.xlsx
# AsExcel/Gian Iphone (feversense)/Burst045.xlsx
# AsExcel/Gian Iphone (feversense)/Burst100.xlsx
# AsExcel/Gian Iphone (feversense)/Burst012.xlsx
# AsExcel/Gian Iphone (feversense)/Burst004.xlsx
# AsExcel/Gian Iphone (feversense)/Burst053.xlsx
# AsExcel/Gian Iphone (feversense)/Burst024.xlsx
# AsExcel/Gian Iphone (feversense)/Burst073.xlsx
# AsExcel/Gian Iphone (feversense)/Burst065.xlsx
# AsExcel/Gian Iphone (feversense)/Burst032.xlsx
# AsExcel/Gian Iphone (feversense)/Burst049.xlsx
# AsExcel/Gian Iphone (feversense)/Burst008.xlsx
# AsExcel/Gian Iphone (feversense)/Burst009.xlsx
# AsExcel/Gian Iphone (feversense)/Burst048.xlsx
# AsExcel/Gian Iphone (feversense)/Burst033.xlsx
# AsExcel/Gian Iphone (feversense)/Burst064.xlsx
# AsExcel/Gian Iphone (feversense)/Burst072.xlsx
# AsExcel/Gian Iphone (feversense)/Burst025.xlsx
# AsExcel/Gian Iphone (feversense)/Burst052.xlsx
# AsExcel/Gian Iphone (feversense)/Burst005.xlsx
# AsExcel/Gian Iphone (feversense)/Burst013.xlsx
# AsExcel/Gian Iphone (feversense)/Burst044.xlsx
# AsExcel/Gian Iphone (feversense)/Burst101.xlsx
# AsExcel/Gian Iphone (feversense)/Burst087.xlsx
# AsExcel/Gian Iphone (feversense)/Burst068.xlsx
# AsExcel/Gian Iphone (feversense)/Burst091.xlsx
# AsExcel/Gian Iphone (feversense)/Burst029.xlsx
# Fever Sense 1
# AsExcel/Fever Sense 1/Burst114.xlsx
# AsExcel/Fever Sense 1/Burst051.xlsx
# AsExcel/Fever Sense 1/Burst143.xlsx
# AsExcel/Fever Sense 1/Burst006.xlsx
# AsExcel/Fever Sense 1/Burst155.xlsx
# AsExcel/Fever Sense 1/Burst010.xlsx
# AsExcel/Fever Sense 1/Burst102.xlsx
# AsExcel/Fever Sense 1/Burst047.xlsx
# AsExcel/Fever Sense 1/Burst084.xlsx
# AsExcel/Fever Sense 1/Burst138.xlsx
# AsExcel/Fever Sense 1/Burst092.xlsx
# AsExcel/Fever Sense 1/Burst118.xlsx
# AsExcel/Fever Sense 1/Burst159.xlsx
# AsExcel/Fever Sense 1/Burst030.xlsx
# AsExcel/Fever Sense 1/Burst067.xlsx
# AsExcel/Fever Sense 1/Burst122.xlsx
# AsExcel/Fever Sense 1/Burst088.xlsx
# AsExcel/Pyle Health 1/Burst078.xlsx
# AsExcel/Pyle Health 1/Burst058.xlsx
# AsExcel/Pyle Health 1/Burst019.xlsx
# AsExcel/Pyle Health 1/Burst035.xlsx
# AsExcel/Pyle Health 1/Burst062.xlsx
# AsExcel/Pyle Health 1/Burst074.xlsx
# AsExcel/Pyle Health 1/Burst023.xlsx
# AsExcel/Pyle Health 1/Burst028.xlsx
# AsExcel/Pyle Health 1/Burst090.xlsx
# AsExcel/Pyle Health 1/Burst086.xlsx
# AsExcel/Pyle Health 1/Burst069.xlsx
# AsExcel/Pyle Health 1/Burst045.xlsx
# AsExcel/Pyle Health 1/Burst100.xlsx
# AsExcel/Pyle Health 1/Burst012.xlsx
# AsExcel/Pyle Health 1/Burst004.xlsx
# AsExcel/Pyle Health 1/Burst053.xlsx
# AsExcel/Pyle Health 1/Burst116.xlsx
# AsExcel/Pyle Health 1/Burst024.xlsx
# AsExcel/Pyle Health 1/Burst073.xlsx
# AsExcel/Pyle Health 1/Burst120.xlsx
# AsExcel/Pyle Health 1/Burst065.xlsx
# AsExcel/Pyle Health 1/Burst032.xlsx
# AsExcel/Pyle Health 1/Burst049.xlsx
# AsExcel/Pyle Health 1/Burst008.xlsx
# AsExcel/Pyle Health 1/Burst009.xlsx
# AsExcel/Pyle Health 1/Burst048.xlsx
# AsExcel/Pyle Health 1/Burst033.xlsx
# AsExcel/Pyle Health 1/Burst121.xlsx
# AsExcel/Pyle Health 1/Burst064.xlsx
# AsExcel/Pyle Health 1/Burst072.xlsx
# AsExcel/Pyle Health 1/Burst025.xlsx
# AsExcel/Pyle Health 1/Burst052.xlsx
# AsExcel/Pyle Health 1/Burst117.xlsx
# AsExcel/Pyle Health 1/Burst005.xlsx
# AsExcel/Pyle Health 1/Burst013.xlsx
# AsExcel/Pyle Health 1/Burst044.xlsx
# AsExcel/Pyle Health 1/Burst101.xlsx
# AsExcel/Pyle Health 1/Burst087.xlsx
# AsExcel/Pyle Health 1/Burst068.xlsx
# AsExcel/Pyle Health 1/Burst091.xlsx
# AsExcel/Pyle Health 1/Burst029.xlsx
# iHealth gluco 2 (search)
# AsExcel/iHealth gluco 2 (search)/Burst114.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst051.xlsx
# 181001
# 180994
# AsExcel/iHealth gluco 2 (search)/Burst143.xlsx
# 0
# 49
# AsExcel/iHealth gluco 2 (search)/Burst006.xlsx
# 2003
# 1997
# AsExcel/iHealth gluco 2 (search)/Burst155.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst010.xlsx
# 0
# 49
# AsExcel/iHealth gluco 2 (search)/Burst102.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst047.xlsx
# 0
# 49
# AsExcel/iHealth gluco 2 (search)/Burst250.xlsx
# 154025
# 154006
# AsExcel/iHealth gluco 2 (search)/Burst196.xlsx
# 120039
# 119997
# AsExcel/iHealth gluco 2 (search)/Burst179.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst207.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst084.xlsx
# 0
# 49
# AsExcel/iHealth gluco 2 (search)/Burst211.xlsx
# 0
# 49
# AsExcel/iHealth gluco 2 (search)/Burst138.xlsx
# 0
# 49
# AsExcel/iHealth gluco 2 (search)/Burst092.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst246.xlsx
# 0
# 49
# AsExcel/iHealth gluco 2 (search)/Burst180.xlsx
# 0
# 49
# AsExcel/iHealth gluco 2 (search)/Burst118.xlsx
# 176002
# 175999
# AsExcel/iHealth gluco 2 (search)/Burst231.xlsx
# 23005
# 22904
# 91018
# 91004
# 125020
# 125017
# AsExcel/iHealth gluco 2 (search)/Burst266.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst159.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst270.xlsx
# 0
# 49
# AsExcel/iHealth gluco 2 (search)/Burst227.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst030.xlsx
# 221992
# 221912
# AsExcel/iHealth gluco 2 (search)/Burst175.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst067.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst122.xlsx
# 169013
# 168981
# 228015
# 227976
# AsExcel/iHealth gluco 2 (search)/Burst088.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst071.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst134.xlsx
# 228659
# 228518
# AsExcel/iHealth gluco 2 (search)/Burst026.xlsx
# 228627
# 228609
# 229714
# 229619
# AsExcel/iHealth gluco 2 (search)/Burst163.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst027.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst162.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst070.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst135.xlsx
# 0
# 49
# AsExcel/iHealth gluco 2 (search)/Burst066.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst123.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst089.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst031.xlsx
# 0
# 49
# AsExcel/iHealth gluco 2 (search)/Burst174.xlsx
# 0
# 49
# AsExcel/iHealth gluco 2 (search)/Burst226.xlsx
# 0
# 49
# AsExcel/iHealth gluco 2 (search)/Burst271.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst158.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst267.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst230.xlsx
# 165025
# 164961
# AsExcel/iHealth gluco 2 (search)/Burst119.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst181.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst247.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst139.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst093.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst210.xlsx
# 4036
# 3994
# AsExcel/iHealth gluco 2 (search)/Burst085.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst206.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst197.xlsx
# 103363
# 103350
# AsExcel/iHealth gluco 2 (search)/Burst178.xlsx
# 110672
# 110671
# AsExcel/iHealth gluco 2 (search)/Burst251.xlsx
# 99475
# 99413
# 127480
# 127471
# AsExcel/iHealth gluco 2 (search)/Burst103.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst046.xlsx
# 161566
# 161503
# 228513
# 228506
# AsExcel/iHealth gluco 2 (search)/Burst154.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst011.xlsx
# 0
# 49
# AsExcel/iHealth gluco 2 (search)/Burst142.xlsx
# 0
# 49
# AsExcel/iHealth gluco 2 (search)/Burst007.xlsx
# 118010
# 117999
# AsExcel/iHealth gluco 2 (search)/Burst115.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst050.xlsx
# 0
# 49
# AsExcel/iHealth gluco 2 (search)/Burst237.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst149.xlsx
# 0
# 49
# AsExcel/iHealth gluco 2 (search)/Burst260.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst108.xlsx
# 0
# 49
# AsExcel/iHealth gluco 2 (search)/Burst221.xlsx
# 133819
# 133794
# 157825
# 157814
# AsExcel/iHealth gluco 2 (search)/Burst036.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst173.xlsx
# 120447
# 120442
# AsExcel/iHealth gluco 2 (search)/Burst061.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst124.xlsx
# 29268
# 29252
# AsExcel/iHealth gluco 2 (search)/Burst077.xlsx
# 30334
# 30240
# 80361
# 80318
# 0
# 228597
# AsExcel/iHealth gluco 2 (search)/Burst098.xlsx
# 157004
# 156989
# 174010
# 174002
# AsExcel/iHealth gluco 2 (search)/Burst132.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst020.xlsx
# 57003
# 56984
# AsExcel/iHealth gluco 2 (search)/Burst165.xlsx
# 101005
# 100996
# 187005
# 187004
# AsExcel/iHealth gluco 2 (search)/Burst112.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst057.xlsx
# 0
# 49
# AsExcel/iHealth gluco 2 (search)/Burst145.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst000.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst153.xlsx
# 17040
# 16992
# 202800
# 202724
# AsExcel/iHealth gluco 2 (search)/Burst016.xlsx
# 135993
# 135960
# AsExcel/iHealth gluco 2 (search)/Burst104.xlsx
# 0
# 49
# AsExcel/iHealth gluco 2 (search)/Burst041.xlsx
# 0
# 49
# AsExcel/iHealth gluco 2 (search)/Burst256.xlsx
# 199569
# 199530
# 229553
# 229533
# AsExcel/iHealth gluco 2 (search)/Burst190.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst201.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst082.xlsx
# 61052
# 60999
# 222059
# 222039
# AsExcel/iHealth gluco 2 (search)/Burst128.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst217.xlsx
# 53415
# 53327
# AsExcel/iHealth gluco 2 (search)/Burst094.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst240.xlsx
# 129489
# 129470
# 187022
# 186932
# 191034
# 191021
# AsExcel/iHealth gluco 2 (search)/Burst186.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst169.xlsx
# 170083
# 169999
# 178106
# 178075
# 185121
# 185104
# AsExcel/iHealth gluco 2 (search)/Burst187.xlsx
# 144006
# 143949
# AsExcel/iHealth gluco 2 (search)/Burst168.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst241.xlsx
# 0
# 49
# AsExcel/iHealth gluco 2 (search)/Burst095.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst216.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst083.xlsx
# 41482
# 41433
# AsExcel/iHealth gluco 2 (search)/Burst129.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst200.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst191.xlsx
# 183813
# 183790
# AsExcel/iHealth gluco 2 (search)/Burst257.xlsx
# 187393
# 187374
# AsExcel/iHealth gluco 2 (search)/Burst105.xlsx
# 0
# 49
# AsExcel/iHealth gluco 2 (search)/Burst040.xlsx
# 23071
# 22998
# AsExcel/iHealth gluco 2 (search)/Burst152.xlsx
# 191978
# 191967
# AsExcel/iHealth gluco 2 (search)/Burst017.xlsx
# 0
# 49
# AsExcel/iHealth gluco 2 (search)/Burst144.xlsx
# 0
# 227725
# AsExcel/iHealth gluco 2 (search)/Burst001.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst113.xlsx
# 164016
# 163998
# AsExcel/iHealth gluco 2 (search)/Burst056.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst021.xlsx
# 0
# 49
# AsExcel/iHealth gluco 2 (search)/Burst164.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst076.xlsx
# 0
# 49
# AsExcel/iHealth gluco 2 (search)/Burst099.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst133.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst060.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst125.xlsx
# 200513
# 200439
# AsExcel/iHealth gluco 2 (search)/Burst037.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst172.xlsx
# 25933
# 25919
# AsExcel/iHealth gluco 2 (search)/Burst220.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst109.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst261.xlsx
# 156672
# 156668
# AsExcel/iHealth gluco 2 (search)/Burst148.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst236.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst167.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst022.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst188.xlsx
# 173017
# 172972
# AsExcel/iHealth gluco 2 (search)/Burst219.xlsx
# 217341
# 217322
# 221369
# 221325
# AsExcel/iHealth gluco 2 (search)/Burst130.xlsx
# 0
# 229515
# AsExcel/iHealth gluco 2 (search)/Burst075.xlsx
# 164050
# 163999
# AsExcel/iHealth gluco 2 (search)/Burst126.xlsx
# 0
# 49
# AsExcel/iHealth gluco 2 (search)/Burst063.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst258.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst171.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst034.xlsx
# 183009
# 182995
# AsExcel/iHealth gluco 2 (search)/Burst223.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst274.xlsx
# 14055
# 13996
# AsExcel/iHealth gluco 2 (search)/Burst018.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst262.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst235.xlsx
# 125878
# 125867
# 0
# 229148
# AsExcel/iHealth gluco 2 (search)/Burst059.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst184.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst242.xlsx
# 179056
# 178960
# AsExcel/iHealth gluco 2 (search)/Burst096.xlsx
# 78037
# 77989
# AsExcel/iHealth gluco 2 (search)/Burst079.xlsx
# 200513
# 200439
# AsExcel/iHealth gluco 2 (search)/Burst215.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst080.xlsx
# 81000
# 80998
# 118005
# 117998
# AsExcel/iHealth gluco 2 (search)/Burst203.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst038.xlsx
# 30373
# 30279
# 80400
# 80357
# 0
# 228636
# AsExcel/iHealth gluco 2 (search)/Burst192.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst254.xlsx
# 131540
# 131536
# 222553
# 222531
# AsExcel/iHealth gluco 2 (search)/Burst043.xlsx
# 88572
# 88551
# 126575
# 126568
# AsExcel/iHealth gluco 2 (search)/Burst106.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst014.xlsx
# 42152
# 42145
# 46167
# 46149
# AsExcel/iHealth gluco 2 (search)/Burst151.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst002.xlsx
# 86362
# 86326
# 0
# 227627
# AsExcel/iHealth gluco 2 (search)/Burst147.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst055.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst110.xlsx
# 53000
# 52997
# AsExcel/iHealth gluco 2 (search)/Burst239.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst238.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst054.xlsx
# 0
# 49
# AsExcel/iHealth gluco 2 (search)/Burst111.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst003.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst146.xlsx
# 223109
# 223082
# AsExcel/iHealth gluco 2 (search)/Burst015.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst150.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst042.xlsx
# 0
# 49
# AsExcel/iHealth gluco 2 (search)/Burst107.xlsx
# 189424
# 189396
# 222399
# 222396
# AsExcel/iHealth gluco 2 (search)/Burst255.xlsx
# 0
# 49
# AsExcel/iHealth gluco 2 (search)/Burst039.xlsx
# 130001
# 129983
# AsExcel/iHealth gluco 2 (search)/Burst193.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst202.xlsx
# 188936
# 188894
# AsExcel/iHealth gluco 2 (search)/Burst081.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst214.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst097.xlsx
# 10010
# 9997
# AsExcel/iHealth gluco 2 (search)/Burst078.xlsx
# 42152
# 42145
# 46167
# 46149
# AsExcel/iHealth gluco 2 (search)/Burst243.xlsx
# 0
# 49
# AsExcel/iHealth gluco 2 (search)/Burst185.xlsx
# 19058
# 18982
# 54266
# 54223
# AsExcel/iHealth gluco 2 (search)/Burst058.xlsx
# 0
# 49
# AsExcel/iHealth gluco 2 (search)/Burst234.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst263.xlsx
# 0
# 49
# AsExcel/iHealth gluco 2 (search)/Burst019.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst222.xlsx
# 6002
# 5995
# AsExcel/iHealth gluco 2 (search)/Burst170.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst035.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst259.xlsx
# 0
# 49
# AsExcel/iHealth gluco 2 (search)/Burst127.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst062.xlsx
# 0
# 49
# AsExcel/iHealth gluco 2 (search)/Burst131.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst074.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst218.xlsx
# 11024
# 10991
# 144347
# 144335
# AsExcel/iHealth gluco 2 (search)/Burst166.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst023.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst189.xlsx
# 4010
# 3995
# AsExcel/iHealth gluco 2 (search)/Burst182.xlsx
# 0
# 49
# AsExcel/iHealth gluco 2 (search)/Burst028.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst244.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst090.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst213.xlsx
# 228814
# 228788
# AsExcel/iHealth gluco 2 (search)/Burst086.xlsx
# 0
# 228813
# AsExcel/iHealth gluco 2 (search)/Burst069.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst205.xlsx
# 67096
# 67059
# AsExcel/iHealth gluco 2 (search)/Burst194.xlsx
# 131579
# 131575
# 222592
# 222570
# AsExcel/iHealth gluco 2 (search)/Burst252.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst045.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst100.xlsx
# 200513
# 200439
# AsExcel/iHealth gluco 2 (search)/Burst229.xlsx
# 17040
# 16992
# 202800
# 202724
# AsExcel/iHealth gluco 2 (search)/Burst012.xlsx
# 120447
# 120442
# AsExcel/iHealth gluco 2 (search)/Burst157.xlsx
# 0
# 49
# AsExcel/iHealth gluco 2 (search)/Burst004.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst141.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst268.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst053.xlsx
# 102446
# 102424
# AsExcel/iHealth gluco 2 (search)/Burst116.xlsx
# 187393
# 187374
# AsExcel/iHealth gluco 2 (search)/Burst248.xlsx
# 93068
# 92993
# 174089
# 174067
# AsExcel/iHealth gluco 2 (search)/Burst161.xlsx
# 128028
# 127999
# AsExcel/iHealth gluco 2 (search)/Burst024.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst136.xlsx
# 14015
# 13997
# AsExcel/iHealth gluco 2 (search)/Burst073.xlsx
# 0
# 49
# AsExcel/iHealth gluco 2 (search)/Burst209.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst120.xlsx
# 120447
# 120442
# AsExcel/iHealth gluco 2 (search)/Burst065.xlsx
# 0
# 228622
# AsExcel/iHealth gluco 2 (search)/Burst177.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst198.xlsx
# 159958
# 159927
# AsExcel/iHealth gluco 2 (search)/Burst032.xlsx
# 189623
# 189610
# AsExcel/iHealth gluco 2 (search)/Burst225.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst049.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst272.xlsx
# 0
# 49
# AsExcel/iHealth gluco 2 (search)/Burst264.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst008.xlsx
# 106576
# 106526
# AsExcel/iHealth gluco 2 (search)/Burst233.xlsx
# 120040
# 119998
# 179050
# 179035
# AsExcel/iHealth gluco 2 (search)/Burst232.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst009.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst265.xlsx
# 12011
# 11995
# 175025
# 175000
# AsExcel/iHealth gluco 2 (search)/Burst273.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst048.xlsx
# 140211
# 140179
# AsExcel/iHealth gluco 2 (search)/Burst224.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst176.xlsx
# 0
# 49
# AsExcel/iHealth gluco 2 (search)/Burst199.xlsx
# 0
# 228059
# AsExcel/iHealth gluco 2 (search)/Burst033.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst121.xlsx
# 110672
# 110671
# AsExcel/iHealth gluco 2 (search)/Burst064.xlsx
# 0
# 49
# AsExcel/iHealth gluco 2 (search)/Burst208.xlsx
# 90504
# 90503
# 202975
# 202949
# AsExcel/iHealth gluco 2 (search)/Burst137.xlsx
# 55003
# 54996
# 73021
# 72985
# AsExcel/iHealth gluco 2 (search)/Burst072.xlsx
# 0
# 49
# AsExcel/iHealth gluco 2 (search)/Burst160.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst025.xlsx
# 79011
# 78999
# AsExcel/iHealth gluco 2 (search)/Burst249.xlsx
# 175546
# 175535
# AsExcel/iHealth gluco 2 (search)/Burst052.xlsx
# 136015
# 135995
# AsExcel/iHealth gluco 2 (search)/Burst117.xlsx
# AsExcel/iHealth gluco 2 (search)/Burst269.xlsx
# AsExcel/iHealth gluco 2 (search)/Bur
# AsExcel/Gian Iphone (omron)/Burst056.xlsx
# AsExcel/Gian Iphone (omron)/Burst021.xlsx
# AsExcel/Gian Iphone (omron)/Burst076.xlsx
# AsExcel/Gian Iphone (omron)/Burst060.xlsx
# AsExcel/Gian Iphone (omron)/Burst037.xlsx
# AsExcel/Gian Iphone (omron)/Burst022.xlsx
# AsExcel/Gian Iphone (omron)/Burst075.xlsx
# AsExcel/Gian Iphone (omron)/Burst063.xlsx
# AsExcel/Gian Iphone (omron)/Burst034.xlsx
# AsExcel/Gian Iphone (omron)/Burst018.xlsx
# AsExcel/Gian Iphone (omron)/Burst059.xlsx
# AsExcel/Gian Iphone (omron)/Burst096.xlsx
# AsExcel/Gian Iphone (omron)/Burst079.xlsx
# AsExcel/Gian Iphone (omron)/Burst080.xlsx
# AsExcel/Gian Iphone (omron)/Burst038.xlsx
# AsExcel/Gian Iphone (omron)/Burst043.xlsx
# AsExcel/Gian Iphone (omron)/Burst014.xlsx
# AsExcel/Gian Iphone (omron)/Burst002.xlsx
# AsExcel/Gian Iphone (omron)/Burst055.xlsx
# AsExcel/Gian Iphone (omron)/Burst054.xlsx
# AsExcel/Gian Iphone (omron)/Burst003.xlsx
# AsExcel/Gian Iphone (omron)/Burst015.xlsx
# AsExcel/Gian Iphone (omron)/Burst042.xlsx
# AsExcel/Gian Iphone (omron)/Burst039.xlsx
# AsExcel/Gian Iphone (omron)/Burst081.xlsx
# AsExcel/Gian Iphone (omron)/Burst078.xlsx
# AsExcel/Gian Iphone (omron)/Burst058.xlsx
# AsExcel/Gian Iphone (omron)/Burst019.xlsx
# AsExcel/Gian Iphone (omron)/Burst035.xlsx
# AsExcel/Gian Iphone (omron)/Burst062.xlsx
# AsExcel/Gian Iphone (omron)/Burst074.xlsx
# AsExcel/Gian Iphone (omron)/Burst023.xlsx
# AsExcel/Gian Iphone (omron)/Burst028.xlsx
# AsExcel/Gian Iphone (omron)/Burst090.xlsx
# AsExcel/Gian Iphone (omron)/Burst086.xlsx
# AsExcel/Gian Iphone (omron)/Burst069.xlsx
# AsExcel/Gian Iphone (omron)/Burst045.xlsx
# AsExcel/Gian Iphone (omron)/Burst012.xlsx
# AsExcel/Gian Iphone (omron)/Burst004.xlsx
# AsExcel/Gian Iphone (omron)/Burst053.xlsx
# AsExcel/Gian Iphone (omron)/Burst024.xlsx
# AsExcel/Gian Iphone (omron)/Burst073.xlsx
# AsExcel/Gian Iphone (omron)/Burst065.xlsx
# AsExcel/Gian Iphone (omron)/Burst032.xlsx
# AsExcel/Gian Iphone (omron)/Burst049.xlsx
# AsExcel/Gian Iphone (omron)/Burst008.xlsx
# AsExcel/Gian Iphone (omron)/Burst009.xlsx
# AsExcel/Gian Iphone (omron)/Burst048.xlsx
# AsExcel/Gian Iphone (omron)/Burst033.xlsx
# AsExcel/Gian Iphone (omron)/Burst064.xlsx
# AsExcel/Gian Iphone (omron)/Burst072.xlsx
# AsExcel/Gian Iphone (omron)/Burst025.xlsx
